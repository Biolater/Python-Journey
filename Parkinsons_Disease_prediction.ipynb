# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.svm import SVC
from sklearn.metrics import accuracy_score

# %%
df = pd.read_csv('/content/parkinsons.csv')

# %%
df.head()
# Out:
#              name  MDVP:Fo(Hz)  MDVP:Fhi(Hz)  MDVP:Flo(Hz)  ...   spread1   spread2        D2       PPE
# 0  phon_R01_S01_1      119.992       157.302        74.997  ... -4.813031  0.266482  2.301442  0.284654
# 1  phon_R01_S01_2      122.400       148.650       113.819  ... -4.075192  0.335590  2.486855  0.368674
# 2  phon_R01_S01_3      116.682       131.111       111.555  ... -4.443179  0.311173  2.342259  0.332634
# 3  phon_R01_S01_4      116.676       137.871       111.366  ... -4.117501  0.334147  2.405554  0.368975
# 4  phon_R01_S01_5      116.014       141.781       110.655  ... -3.747787  0.234513  2.332180  0.410335
#
# [5 rows x 24 columns]

# %%
df['status'].value_counts()
# Out:
# status
# 1    147
# 0     48
# Name: count, dtype: int64

# %%
df.shape
# Out:
# (195, 24)

# %%
df.isnull().sum()
# Out:
# name                0
# MDVP:Fo(Hz)         0
# MDVP:Fhi(Hz)        0
# MDVP:Flo(Hz)        0
# MDVP:Jitter(%)      0
# MDVP:Jitter(Abs)    0
# MDVP:RAP            0
# MDVP:PPQ            0
# Jitter:DDP          0
# MDVP:Shimmer        0
# MDVP:Shimmer(dB)    0
# Shimmer:APQ3        0
# Shimmer:APQ5        0
# MDVP:APQ            0
# Shimmer:DDA         0
# NHR                 0
# HNR                 0
# status              0
# RPDE                0
# DFA                 0
# spread1             0
# spread2             0
# D2                  0
# PPE                 0
# dtype: int64

# %%
X = df.drop(columns=['name', 'status'], axis=1)
Y = df['status']

# %%
X.head()
# Out:
#    MDVP:Fo(Hz)  MDVP:Fhi(Hz)  MDVP:Flo(Hz)  MDVP:Jitter(%)  ...   spread1   spread2        D2       PPE
# 0      119.992       157.302        74.997         0.00784  ... -4.813031  0.266482  2.301442  0.284654
# 1      122.400       148.650       113.819         0.00968  ... -4.075192  0.335590  2.486855  0.368674
# 2      116.682       131.111       111.555         0.01050  ... -4.443179  0.311173  2.342259  0.332634
# 3      116.676       137.871       111.366         0.00997  ... -4.117501  0.334147  2.405554  0.368975
# 4      116.014       141.781       110.655         0.01284  ... -3.747787  0.234513  2.332180  0.410335
#
# [5 rows x 22 columns]

# %%
scaler = StandardScaler()

# %%
X_standardized = scaler.fit_transform(X)

# %%
X = pd.DataFrame(X_standardized, columns=X.columns)

# %%
X.head()
# Out:
#    MDVP:Fo(Hz)  MDVP:Fhi(Hz)  MDVP:Flo(Hz)  MDVP:Jitter(%)  ...   spread1   spread2        D2       PPE
# 0    -0.829300     -0.436165     -0.952037        0.334914  ...  0.801323  0.480477 -0.210531  0.868886
# 1    -0.770972     -0.530974     -0.057721        0.715418  ...  1.479853  1.311185  0.275077  1.803605
# 2    -0.909476     -0.723168     -0.109875        0.884991  ...  1.141445  1.017682 -0.103629  1.402661
# 3    -0.909622     -0.649092     -0.114229        0.775389  ...  1.440945  1.293840  0.062145  1.806954
# 4    -0.925657     -0.606245     -0.130608        1.368893  ...  1.780940  0.096195 -0.130026  2.267082
#
# [5 rows x 22 columns]

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2, random_state=2)

# %%
model = SVC(kernel='linear')

# %%
Y.head()
# Out:
# 0    1
# 1    1
# 2    1
# 3    1
# 4    1
# Name: status, dtype: int64

# %%
model.fit(X_train, Y_train)
# Out:
# SVC(kernel='linear')

# %%
model.score(X_train, Y_train)
# Out:
# 0.8846153846153846

# %%
model.score(X_test, Y_test)
# Out:
# 0.8461538461538461

# %%
input_data = (197.076,206.896,192.055,0.00289,0.00001,0.00166,0.00168,0.00498,0.01098,0.097,0.00563,0.0068,0.00802,0.01689,0.00339,26.775,0.422229,0.741367,-7.3483,0.177551,1.743867,0.085569)
input_data_as_numpy_array = np.asarray(input_data)
input_data_reshaped = input_data_as_numpy_array.reshape(1,-1)
std_data = scaler.transform(input_data_reshaped)
prediction = model.predict(std_data)
if (prediction[0] == 0):
  print("The Person does not have Parkinsons Disease")
else:
  print("The Person has Parkinsons")
# Out:
# The Person does not have Parkinsons Disease
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but SVC was fitted with feature names
#   warnings.warn(
